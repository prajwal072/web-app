# %% [markdown]
# <a href="https://colab.research.google.com/github/prajwal072/web-app/blob/main/basic_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
# Map
def square(x):
  return x**2

square(3)
numbers=[1,2,3,4,5,6]
# Out:
# 9

# %%
numbers=[1,2,3,4,5,6]
list(map(square,numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
num1=[1,2,3]
num2=[4,5,6]
list(map(lambda x,y:x+y,num1,num2))
# Out:
# [5, 7, 9]

# %%
def even (num):
  if num%2==0:
    return True

num=[1,2,3,4,5,6,7,8]
list(filter(even,num))
# Out:
# [2, 4, 6, 8]

# %%
num=[1,2,3,4,5,6,7,8]
list(filter(lambda x:x>5,num))
# Out:
# [6, 7, 8]

# %%
num1=[1,2,3]
num2=[4,5,6]
list(filter(lambda x:x>=2, num1))
# Out:
# [2, 3]

# %%
# Exception Handling
try:
  a=10/3

except Exception as ex:
  print(ex)

else:
  print("Execution of else block")

finally:
  print("Finally Executed")
# Out:
# Execution of else block
# Finally Executed
